# %% [markdown]
# # 14. Pacman with AI
# ## 14.1. Practical Session 3: Pacman with AI

# %% [markdown]
# ## Heuristic ideas

# %% [markdown]
# - Go close to "power capsules"
#
# - When under "power capsule" effect, do the following:
#     - Avoid further "power capsules"
#     - Chase ghosts

# %% [markdown]
# - Avoid repeating moves (past moves should be stored as buffer)

# %% [markdown]
# ### "Power capsule" heuristics
